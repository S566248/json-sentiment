# %% [markdown]
# # Web Mining and Applied NLP (44-620)
#
# ## Requests, JSON, and NLP
#
# ### Student Name: Tyler Stanton
#
# ### GitHub Repo: https://github.com/S566248/json-sentiment
#
# Perform the tasks described in the Markdown cells below.  When you have completed the assignment make sure your code cells have all been run (and have output beneath them) and ensure you have committed and pushed ALL of your changes to your assignment repository.
#
# Make sure you have [installed spaCy and its pipeline](https://spacy.io/usage#quickstart) and [spaCyTextBlob](https://spacy.io/universe/project/spacy-textblob)
#
# Every question that requires you to write code will have a code cell underneath it; you may either write your entire solution in that cell or write it in a python file (`.py`), then import and run the appropriate code to answer the question.
#
# This assignment requires that you write additional files (either JSON or pickle files); make sure to submit those files in your repository as well.

# %% [markdown]
# Starting Code
# Getting all prereqs installed

# %%
# Create and activate a Python virtual environment. 
# Before starting the project, try all these imports FIRST
# Address any errors you get running this code cell 
# by installing the necessary packages into your active Python environment.
# Try to resolve issues using your materials and the web.
# If that doesn't work, ask for help in the discussion forums.
# You can't complete the exercises until you import these - start early! 
# We also import json and pickle (included in the Python Standard Library).

import json
import pickle

import requests
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

print('All prereqs installed.')
# !pip list
# Out:
# All prereqs installed.
# Package                  Version
# ------------------------ --------------------
# annotated-types          0.6.0
# anyio                    3.7.0
# appdirs                  1.4.4
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asgiref                  3.7.2
# astroid                  2.15.5
# asttokens                2.2.1
# async-lru                2.0.2
# attrs                    23.1.0
# Babel                    2.12.1
# backcall                 0.2.0
# beautifulsoup4           4.12.2
# black                    23.7.0
# bleach                   6.0.0
# blis                     0.7.9
# build                    0.10.0
# catalogue                2.0.8
# certifi                  2023.5.7
# cffi                     1.15.1
# charset-normalizer       3.1.0
# click                    8.1.3
# cloudpathlib             0.16.0
# colorama                 0.4.6
# comm                     0.1.3
# confection               0.0.4
# contextvars              2.4
# contourpy                1.0.7
# cycler                   0.11.0
# cymem                    2.0.7
# debugpy                  1.6.7
# decorator                5.1.1
# defusedxml               0.7.1
# dill                     0.3.6
# dodgy                    0.2.1
# dweepy                   0.3.0
# en-core-web-sm           3.7.1
# executing                1.2.0
# fastjsonschema           2.17.1
# flake8                   5.0.4
# flake8-polyfill          1.0.2
# fonttools                4.39.4
# fqdn                     1.5.1
# geographiclib            2.0
# geopy                    2.3.0
# gitdb                    4.0.10
# GitPython                3.1.31
# h11                      0.14.0
# htmltools                0.2.1
# idna                     3.4
# imageio                  2.30.0
# immutables               0.19
# ipykernel                6.23.1
# ipython                  8.14.0
# ipywidgets               8.0.6
# isoduration              20.11.0
# isort                    5.12.0
# jedi                     0.18.2
# Jinja2                   3.1.2
# joblib                   1.2.0
# json5                    0.9.14
# jsonpointer              2.3
# jsonschema               4.17.3
# jupyter_client           8.2.0
# jupyter_core             5.3.0
# jupyter-events           0.6.3
# jupyter-lsp              2.2.0
# jupyter_server           2.6.0
# jupyter_server_terminals 0.4.4
# jupyterlab               4.0.1
# jupyterlab-pygments      0.2.2
# jupyterlab_server        2.22.1
# jupyterlab-widgets       3.0.7
# kiwisolver               1.4.4
# langcodes                3.3.0
# lazy-object-proxy        1.9.0
# linkify-it-py            2.0.2
# markdown-it-py           3.0.0
# MarkupSafe               2.1.2
# matplotlib               3.7.1
# matplotlib-inline        0.1.6
# mccabe                   0.7.0
# mdit-py-plugins          0.4.0
# mdurl                    0.1.2
# mistune                  2.0.5
# murmurhash               1.0.9
# mypy-extensions          1.0.0
# nbclient                 0.8.0
# nbconvert                7.4.0
# nbformat                 5.9.0
# nest-asyncio             1.5.6
# nltk                     3.8.1
# nodeenv                  1.8.0
# notebook_shim            0.2.3
# numpy                    1.24.3
# overrides                7.3.1
# packaging                23.1
# pandas                   2.0.2
# pandocfilters            1.5.0
# parso                    0.8.3
# pathspec                 0.11.1
# pathy                    0.10.1
# pep8-naming              0.10.0
# pickleshare              0.7.5
# Pillow                   9.5.0
# pip                      24.0
# platformdirs             3.5.1
# preshed                  3.0.8
# prometheus-client        0.17.0
# prompt-toolkit           3.0.38
# prospector               1.10.2
# psutil                   5.9.5
# pure-eval                0.2.2
# pycodestyle              2.9.1
# pycparser                2.21
# pydantic                 1.10.8
# pydantic_core            2.16.3
# pydocstyle               6.3.0
# pyflakes                 2.5.0
# Pygments                 2.15.1
# PyHyphen                 4.0.3
# PyJWT                    2.7.0
# pylint                   2.17.4
# pylint-celery            0.3
# pylint-django            2.5.3
# pylint-flask             0.6
# pylint-plugin-utils      0.7
# pyparsing                3.0.9
# pyproject_hooks          1.0.0
# pyright                  1.1.317
# pyrsistent               0.19.3
# python-dateutil          2.8.2
# python-json-logger       2.0.7
# python-multipart         0.0.6
# pytz                     2023.3
# pywin32                  306
# pywinpty                 2.0.10
# PyYAML                   6.0
# pyzmq                    25.1.0
# regex                    2023.5.5
# requests                 2.31.0
# requirements-detector    1.2.2
# rfc3339-validator        0.1.4
# rfc3986-validator        0.1.1
# rsconnect-python         1.18.1.dev4+g9e7314b
# ruff                     0.0.278
# scikit-learn             1.2.2
# scipy                    1.10.1
# seaborn                  0.12.2
# semver                   2.13.0
# Send2Trash               1.8.2
# setoptconf-tmp           0.3.1
# setuptools               65.5.0
# shiny                    0.4.0
# shinyswatch              0.2.4
# six                      1.16.0
# smart-open               6.3.0
# smmap                    5.0.0
# sniffio                  1.3.0
# snowballstemmer          2.2.0
# soupsieve                2.4.1
# spacy                    3.5.3
# spacy-legacy             3.0.12
# spacy-loggers            1.0.4
# spacytextblob            4.0.0
# srsly                    2.4.6
# stack-data               0.6.2
# starlette                0.28.0
# terminado                0.17.1
# textatistic              0.0.1
# textblob                 0.17.1
# thinc                    8.1.10
# threadpoolctl            3.1.0
# tinycss2                 1.2.1
# toml                     0.10.2
# tomlkit                  0.11.8
# tornado                  6.3.2
# tqdm                     4.65.0
# traitlets                5.9.0
# typer                    0.7.0
# typing_extensions        4.6.3
# tzdata                   2023.3
# uc-micro-py              1.0.2
# uri-template             1.2.0
# urllib3                  2.0.2
# uvicorn                  0.22.0
# voila                    0.0.0
# wasabi                   1.1.1
# watchfiles               0.19.0
# wcwidth                  0.2.6
# weasel                   0.3.4
# webcolors                1.13
# webencodings             0.5.1
# websocket-client         1.5.2
# websockets               11.0.3
# wheel                    0.40.0
# widgetsnbextension       4.0.7
# wrapt                    1.15.0
# XStatic-bootswatch       3.3.7.0

# %% [markdown]
# 1. The following code accesses the [lyrics.ovh](https://lyricsovh.docs.apiary.io/#reference/0/lyrics-of-a-song/search) public api, searches for the lyrics of a song, and stores it in a dictionary object.  Write the resulting json to a file (either a JSON file or a pickle file; you choose). You will read in the contents of this file for future questions so we do not need to frequently access the API.

# %% [markdown]
# Question 1: Writing the dictionary for the website

# %%
import requests
import json

# Access the API and load the JSON response into a dictionary
result = json.loads(requests.get('https://api.lyrics.ovh/v1/They Might Be Giants/Birdhouse in your soul').text)

# Write the dictionary to a JSON file
with open('lyrics.json', 'w') as f:
    json.dump(result, f)

# %% [markdown]
# 2. Read in the contents of your file.  Print the lyrics of the song (not the entire dictionary!) and use spaCyTextBlob to perform sentiment analysis on the lyrics.  Print the polarity score of the sentiment analysis.  Given that the range of the polarity score is `[-1.0,1.0]` which corresponds to how positive or negative the text in question is, do you think the lyrics have a more positive or negative connotaion?  Answer this question in a comment in your code cell.

# %% [markdown]
# Question 2: Print the lyrics and review the polarity score

# %%
import json
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

# Load spaCy model and add SpacyTextBlob to the pipeline
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')

# Read in the contents of the JSON file
with open('lyrics.json', 'r') as f:
    data = json.load(f)

# Extract the lyrics from the JSON data
lyrics = data['lyrics']

# Print the lyrics of the song
print("Lyrics of the song:")
print(lyrics)
print()

# Analyze sentiment using spaCyTextBlob
doc = nlp(lyrics)

# Print the polarity score of the sentiment analysis
print("Polarity score:", doc._.polarity)


# A polarity score closer to 1.0 indicates a positive sentiment,
# so these lyrics have a more positive sentiment as they are
# closer to 1.0 and -1.0.
# Out:
# ---------------------------------------------------------------------------
# RegistryError                             Traceback (most recent call last)
# Cell In[4], line 6
#       3 from spacytextblob.spacytextblob import SpacyTextBlob
#       5 # Load spaCy model and add SpacyTextBlob to the pipeline
# ----> 6 nlp = spacy.load('en_core_web_sm')
#       7 nlp.add_pipe('spacytextblob')
#       9 # Read in the contents of the JSON file
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#      57         disable=disable,
#      58         enable=enable,
#      59         exclude=exclude,
#      60         config=config,
#      61     )
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:442, in load_model(name, vocab, disable, enable, exclude, config)
#     440     return get_lang_class(name.replace("blank:", ""))()
#     441 if is_package(name):  # installed as package
# --> 442     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     443 if Path(name).exists():  # path to model data directory
#     444     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:478, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     461 """Load a model from an installed package.
#     462
#     463 name (str): The package name.
#    (...)
#     475 RETURNS (Language): The loaded nlp object.
#     476 """
#     477 cls = importlib.import_module(name)
# --> 478 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\en_core_web_sm\__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:659, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     657 if not model_path.exists():
#     658     raise IOError(Errors.E052.format(path=data_path))
# --> 659 return load_model_from_path(
#     660     data_path,
#     661     vocab=vocab,
#     662     meta=meta,
#     663     disable=disable,
#     664     enable=enable,
#     665     exclude=exclude,
#     666     config=config,
#     667 )
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:516, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     514 overrides = dict_to_dot(config)
#     515 config = load_config(config_path, overrides=overrides)
# --> 516 nlp = load_model_from_config(
#     517     config,
#     518     vocab=vocab,
#     519     disable=disable,
#     520     enable=enable,
#     521     exclude=exclude,
#     522     meta=meta,
#     523 )
#     524 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:564, in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     561 # This will automatically handle all codes registered via the languages
#     562 # registry, including custom subclasses provided via entry points
#     563 lang_cls = get_lang_class(nlp_config["lang"])
# --> 564 nlp = lang_cls.from_config(
#     565     config,
#     566     vocab=vocab,
#     567     disable=disable,
#     568     enable=enable,
#     569     exclude=exclude,
#     570     auto_fill=auto_fill,
#     571     validate=validate,
#     572     meta=meta,
#     573 )
#     574 return nlp
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\language.py:1749, in Language.from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1747     filled["pretraining"] = orig_pretraining
#    1748     config["pretraining"] = orig_pretraining
# -> 1749 resolved_nlp = registry.resolve(
#    1750     filled["nlp"], validate=validate, schema=ConfigSchemaNlp
#    1751 )
#    1752 create_tokenizer = resolved_nlp["tokenizer"]
#    1753 before_creation = resolved_nlp["before_creation"]
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:728, in registry.resolve(cls, config, schema, overrides, validate)
#     719 @classmethod
#     720 def resolve(
#     721     cls,
#    (...)
#     726     validate: bool = True,
#     727 ) -> Dict[str, Any]:
# --> 728     resolved, _ = cls._make(
#     729         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     730     )
#     731     return resolved
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:777, in registry._make(cls, config, schema, overrides, resolve, validate)
#     775 if not is_interpolated:
#     776     config = Config(orig_config).interpolate()
# --> 777 filled, _, resolved = cls._fill(
#     778     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     779 )
#     780 filled = Config(filled, section_order=section_order)
#     781 # Check that overrides didn't include invalid properties not in config
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:831, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     829     field = schema.__fields__[key]
#     830     schema.__fields__[key] = copy_model_field(field, Any)
# --> 831 promise_schema = cls.make_promise_schema(value, resolve=resolve)
#     832 filled[key], validation[v_key], final[key] = cls._fill(
#     833     value,
#     834     promise_schema,
#    (...)
#     838     overrides=overrides,
#     839 )
#     840 reg_name, func_name = cls.get_constructor(final[key])
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:1023, in registry.make_promise_schema(cls, obj, resolve)
#    1021 if not resolve and not cls.has(reg_name, func_name):
#    1022     return EmptySchema
# -> 1023 func = cls.get(reg_name, func_name)
#    1024 # Read the argument annotations and defaults from the function signature
#    1025 id_keys = [k for k in obj.keys() if k.startswith("@")]
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:128, in registry.get(cls, registry_name, func_name)
#     126 if not hasattr(cls, registry_name):
#     127     names = ", ".join(cls.get_registry_names()) or "none"
# --> 128     raise RegistryError(Errors.E892.format(name=registry_name, available=names))
#     129 reg = getattr(cls, registry_name)
#     130 try:
#
# RegistryError: [E892] Unknown function registry: 'vectors'.
#
# Available names: architectures, augmenters, batchers, callbacks, cli, datasets, displacy_colors, factories, initializers, languages, layers, lemmatizers, loggers, lookups, losses, misc, models, ops, optimizers, readers, schedules, scorers, tokenizers

# %% [markdown]
# 3. Write a function that takes an artist, song, and filename, accesses the lyrics.ovh api to get the song lyrics, and writes the results to the specified filename.  Test this function by getting the lyrics to any four songs of your choice and storing them in different files.

# %% [markdown]
# Question 3: Create new files from different songs

# %%
import requests
import json

def get_lyrics(artist, song, filename):

    # Access the API and load the JSON response into a dictionary
    result = json.loads(requests.get(f'https://api.lyrics.ovh/v1/{artist}/{song}').text)

    # Write the lyrics to a file
    with open(filename, 'w') as f:
        if 'lyrics' in result:
            f.write(result['lyrics'])
        else:
            f.write("Lyrics not found.")

# Test the function by getting the lyrics of four songs and storing them in different files
get_lyrics("Owl City", "Fireflies", "fireflies_lyrics.txt")
get_lyrics("Kelly Clarkson", "Already Gone", "already_gone_lyrics.txt")
get_lyrics("Hot Chelle Rae", "Tonight Tonight", "tonight_tonight_lyrics.txt")
get_lyrics("Adele", "Someone Like You", "someone_like_you_lyrics.txt")

# %% [markdown]
# 4. Write a function that takes the name of a file that contains song lyrics, loads the file, performs sentiment analysis, and returns the polarity score.  Use this function to print the polarity scores (with the name of the song) of the three files you created in question 3.  Does the reported polarity match your understanding of the song's lyrics? Why or why not do you think that might be?  Answer the questions in either a comment in the code cell or a markdown cell under the code cell.

# %% [markdown]
# Question 4: Run analysis and review polarity of new songs

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

def get_polarity_score(filename):

    # Load spaCy model and add SpacyTextBlob to the pipeline
    nlp = spacy.load('en_core_web_sm')
    nlp.add_pipe('spacytextblob')

    # Read the lyrics from the file
    with open(filename, 'r') as f:
        lyrics = f.read()

    # Analyze sentiment using spaCyTextBlob
    doc = nlp(lyrics)

    # Return the polarity score
    return doc._.polarity

# Test the function by printing the polarity scores of the three files created in question 3
print("Polarity score for Fireflies:", get_polarity_score("fireflies_lyrics.txt"))
print("Polarity score for Already Gone:", get_polarity_score("already_gone_lyrics.txt"))
print("Polarity score for Someone Like You:", get_polarity_score("someone_like_you_lyrics.txt"))
print("Polarity score for Tonight Tonight:", get_polarity_score("tonight_tonight_lyrics.txt"))
# Out:
# ---------------------------------------------------------------------------
# RegistryError                             Traceback (most recent call last)
# Cell In[6], line 21
#      18     return doc._.polarity
#      20 # Test the function by printing the polarity scores of the three files created in question 3
# ---> 21 print("Polarity score for Fireflies:", get_polarity_score("fireflies_lyrics.txt"))
#      22 print("Polarity score for Already Gone:", get_polarity_score("already_gone_lyrics.txt"))
#      23 print("Polarity score for Someone Like You:", get_polarity_score("someone_like_you_lyrics.txt"))
#
# Cell In[6], line 7, in get_polarity_score(filename)
#       4 def get_polarity_score(filename):
#       5
#       6     # Load spaCy model and add SpacyTextBlob to the pipeline
# ----> 7     nlp = spacy.load('en_core_web_sm')
#       8     nlp.add_pipe('spacytextblob')
#      10     # Read the lyrics from the file
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#      57         disable=disable,
#      58         enable=enable,
#      59         exclude=exclude,
#      60         config=config,
#      61     )
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:442, in load_model(name, vocab, disable, enable, exclude, config)
#     440     return get_lang_class(name.replace("blank:", ""))()
#     441 if is_package(name):  # installed as package
# --> 442     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     443 if Path(name).exists():  # path to model data directory
#     444     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:478, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     461 """Load a model from an installed package.
#     462
#     463 name (str): The package name.
#    (...)
#     475 RETURNS (Language): The loaded nlp object.
#     476 """
#     477 cls = importlib.import_module(name)
# --> 478 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\en_core_web_sm\__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:659, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     657 if not model_path.exists():
#     658     raise IOError(Errors.E052.format(path=data_path))
# --> 659 return load_model_from_path(
#     660     data_path,
#     661     vocab=vocab,
#     662     meta=meta,
#     663     disable=disable,
#     664     enable=enable,
#     665     exclude=exclude,
#     666     config=config,
#     667 )
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:516, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     514 overrides = dict_to_dot(config)
#     515 config = load_config(config_path, overrides=overrides)
# --> 516 nlp = load_model_from_config(
#     517     config,
#     518     vocab=vocab,
#     519     disable=disable,
#     520     enable=enable,
#     521     exclude=exclude,
#     522     meta=meta,
#     523 )
#     524 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:564, in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     561 # This will automatically handle all codes registered via the languages
#     562 # registry, including custom subclasses provided via entry points
#     563 lang_cls = get_lang_class(nlp_config["lang"])
# --> 564 nlp = lang_cls.from_config(
#     565     config,
#     566     vocab=vocab,
#     567     disable=disable,
#     568     enable=enable,
#     569     exclude=exclude,
#     570     auto_fill=auto_fill,
#     571     validate=validate,
#     572     meta=meta,
#     573 )
#     574 return nlp
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\language.py:1749, in Language.from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1747     filled["pretraining"] = orig_pretraining
#    1748     config["pretraining"] = orig_pretraining
# -> 1749 resolved_nlp = registry.resolve(
#    1750     filled["nlp"], validate=validate, schema=ConfigSchemaNlp
#    1751 )
#    1752 create_tokenizer = resolved_nlp["tokenizer"]
#    1753 before_creation = resolved_nlp["before_creation"]
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:728, in registry.resolve(cls, config, schema, overrides, validate)
#     719 @classmethod
#     720 def resolve(
#     721     cls,
#    (...)
#     726     validate: bool = True,
#     727 ) -> Dict[str, Any]:
# --> 728     resolved, _ = cls._make(
#     729         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     730     )
#     731     return resolved
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:777, in registry._make(cls, config, schema, overrides, resolve, validate)
#     775 if not is_interpolated:
#     776     config = Config(orig_config).interpolate()
# --> 777 filled, _, resolved = cls._fill(
#     778     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     779 )
#     780 filled = Config(filled, section_order=section_order)
#     781 # Check that overrides didn't include invalid properties not in config
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:831, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     829     field = schema.__fields__[key]
#     830     schema.__fields__[key] = copy_model_field(field, Any)
# --> 831 promise_schema = cls.make_promise_schema(value, resolve=resolve)
#     832 filled[key], validation[v_key], final[key] = cls._fill(
#     833     value,
#     834     promise_schema,
#    (...)
#     838     overrides=overrides,
#     839 )
#     840 reg_name, func_name = cls.get_constructor(final[key])
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\confection\__init__.py:1023, in registry.make_promise_schema(cls, obj, resolve)
#    1021 if not resolve and not cls.has(reg_name, func_name):
#    1022     return EmptySchema
# -> 1023 func = cls.get(reg_name, func_name)
#    1024 # Read the argument annotations and defaults from the function signature
#    1025 id_keys = [k for k in obj.keys() if k.startswith("@")]
#
# File c:\Users\Mikayla Rietgraf\NWMS Masters\NLP\Module4\json-sentiment\.venv\Lib\site-packages\spacy\util.py:128, in registry.get(cls, registry_name, func_name)
#     126 if not hasattr(cls, registry_name):
#     127     names = ", ".join(cls.get_registry_names()) or "none"
# --> 128     raise RegistryError(Errors.E892.format(name=registry_name, available=names))
#     129 reg = getattr(cls, registry_name)
#     130 try:
#
# RegistryError: [E892] Unknown function registry: 'vectors'.
#
# Available names: architectures, augmenters, batchers, callbacks, cli, datasets, displacy_colors, factories, initializers, languages, layers, lemmatizers, loggers, lookups, losses, misc, models, ops, optimizers, readers, schedules, scorers, tokenizers
